# %% [markdown]
# # Battle for Neighbourhoods

# %% [markdown]
# ### Capstone Project - Final Project

# %% [markdown]
# #### Background
#
# The emergence of location services has created new capabilities and existing businesses are finding new threats every day. Start-ups leveraging new technologies and innovative business models have continued to disrupt and influence how customers choose their travel destinations, activities to engage in, places to stay and eat, and the number of travelers suitable for a specific season. To remain competitive, businesses have embraced use of location data to identify consumer patterns, tastes, and trends. Location data is available from a number of social media platforms including Google maps, Facebook check-in data, location reviews on sites like TripAdvisor and Booking, Foursquare among other location data providers. After learning data science, two friends who have a young start-up travel business decide to change the business model by applying data science skills and techniques. It is their believe that data science will improve their customer experience, grow customer loyalty, promote the company brand and set the company out as a choice travel agent.

# %% [markdown]
# #### Problem
# It is difficult for start-ups to compete with stablished businesses, especially if they both provide the same services, unless there is a unique methodology that sets them apart. That being said, it is usually easier for start-ups to embrace the technology revolution and offer innovative solution for customers allowing them to stay competitive in the market. One example is, suppose a start-up is offering recommendation on travel itinerary to their customers however, their current methodology has not yielded enough growth in allowing them to stay competitive in the market. The company might close down if this trend continues.

# %% [markdown]
# #### Applying data science to solve the problem
# To help increase their market share, the company decided to include data analytics in their methodology in recommending travel itinerary to customers based on a set of criteria. That being said, the company intends to collect location data from Foursquare. Supposing a recent customer has asked the company to recommend a travel destination between Virginia Beach, VA and Pompano Beach with special emphasis on coffee shops. Hence, the data collection and analysis will involve comparison of these two locations to determine which is the best location to recommend based on the criteria given.

# %% [markdown]
# #### Methodology
# The data was accessed through FourSquare API interface. The data was then visualized using folium package to see the number of coffee shops near Pompano and Virginia Beach. The customer requirements included a bit of shopping places as well as good sites to see. The most important requirement was good coffee shop. The data extracted from the FourSquare API will be arranged as a dataframe for visualization.

# %% [markdown]
# ### Results
# #### Virginia Beach
# We found 14 coffee shops. The nearest was Starbucks, which was 700 meters from the beach. It has a rating of 7.6 and has 32 tips. The coffee shops are located a bit far from each other indicating that the area has lesser concentration of coffee customers.
# #### Pompano Beach
# We found 14 coffee shop. The nearest Starbucks coffee was a bit far, 2398 meters. It has a rating of 8.2 and 21 tips. The coffee shops are closely located to each other meaning that the area attracts more customers.
#
# #### Discussion
# Based on the customer rquirements for good coffee shops and analysis presented above, we will recommend Pompano Beach to our customer. We hope that the higher concentration of coffee shops in Pompano as well as availability of quality coffee shops like Starbucks will give our customer good selection and variety.
#
# #### Conclusion
# By applying data science principles, we have been able to compare two locations and visualize the distribution of coffee shops in the area. We hope this will differentiate our product from our competitors and helps us to customize travel experiences for our customers.

# %% [markdown]
# ## Code starts here

# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
import requests
print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '1GCGK0NEFVQIG41JOZDL1RGYWORMBBSG0SLBIG1GHFWIQBFN' # your Foursquare ID
CLIENT_SECRET = 'KBFKCJFMGSB5XH50VKACBIFANAPYG5O5YWJ4KK3OJQN0UXKU' # your Foursquare Secret
VERSION = '20180929'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1GCGK0NEFVQIG41JOZDL1RGYWORMBBSG0SLBIG1GHFWIQBFN
# CLIENT_SECRET:KBFKCJFMGSB5XH50VKACBIFANAPYG5O5YWJ4KK3OJQN0UXKU

# %%
city = 'Virginia Beach, VA'
geolocator = Nominatim()
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 36.8529841 -75.9774183

# %%
search_query = 'Coffee'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1GCGK0NEFVQIG41JOZDL1RGYWORMBBSG0SLBIG1GHFWIQBFN&client_secret=KBFKCJFMGSB5XH50VKACBIFANAPYG5O5YWJ4KK3OJQN0UXKU&ll=36.8529841,-75.9774183&v=20180929&query=Coffee&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c61a6641ed2192b552e780a'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '57487afd498e2665b707a63b',
#     'location': {'address': '607 19th St',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'crossStreet': 'Mediterranean Street',
#      'distance': 882,
#      'formattedAddress': ['607 19th St (Mediterranean Street)',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.846105403127005,
#        'lng': -75.98235051569591}],
#      'lat': 36.846105403127005,
#      'lng': -75.98235051569591,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Three Ships Coffee Bar and Roastery',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b816977f964a52085a430e3',
#     'location': {'address': '619 18th St',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 1016,
#      'formattedAddress': ['619 18th St',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.845091600087486,
#        'lng': -75.98315821519844}],
#      'lat': 36.845091600087486,
#      'lng': -75.98315821519844,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Bad Ass Coffee',
#     'referralId': 'v-1549903460',
#     'venuePage': {'id': '35383790'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '4ce6d6419f776ea8f9335422',
#     'location': {'address': '3198 Pacific Avenur',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 843,
#      'formattedAddress': ['3198 Pacific Avenur',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.86015886424331,
#        'lng': -75.98045399704473}],
#      'lat': 36.86015886424331,
#      'lng': -75.98045399704473,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Perked Up Coffee Cafe',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4cb1bedfcbab236a5e24ab73',
#     'location': {'address': '1005 Atlantic Ave',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 1622,
#      'formattedAddress': ['1005 Atlantic Ave',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.838952522337316,
#        'lng': -75.97249804295173}],
#      'lat': 36.838952522337316,
#      'lng': -75.97249804295173,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Beach Coffee Co.',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f321d0319836c91c7b73c2f',
#     'location': {'address': '3198 Pacific Ave',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 704,
#      'formattedAddress': ['3198 Pacific Ave',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.859136,
#        'lng': -75.979261}],
#      'lat': 36.859136,
#      'lng': -75.979261,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Cape Henry Coffee',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '4c7ad1e781bca093a8b60115',
#     'location': {'address': '1719 Atlantic Ave',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 822,
#      'formattedAddress': ['1719 Atlantic Ave',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.846,
#        'lng': -75.97442015}],
#      'lat': 36.846,
#      'lng': -75.97442015,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Maui Wowi Hawaiian Coffee',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4ba65919f964a520034939e3',
#     'location': {'address': '3601 Atlantic Ave',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'crossStreet': 'at 36th St',
#      'distance': 1270,
#      'formattedAddress': ['3601 Atlantic Ave (at 36th St)',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.8643338388835,
#        'lng': -75.97895220378987}],
#      'lat': 36.8643338388835,
#      'lng': -75.97895220378987,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Belvedere Coffee Shop',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b5459abf964a52048b827e3',
#     'location': {'address': '241 Laskin Road',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 700,
#      'formattedAddress': ['241 Laskin Road',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.85915482880249,
#        'lng': -75.97897582675576}],
#      'lat': 36.85915482880249,
#      'lng': -75.97897582675576,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Starbucks',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4c1fe784a34cd13a231a7d74',
#     'location': {'address': '3737 Atlantic Ave',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 1435,
#      'formattedAddress': ['3737 Atlantic Ave',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.8657776,
#        'lng': -75.9794422}],
#      'lat': 36.8657776,
#      'lng': -75.9794422,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Courtyard by Marriott',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b87d477f964a52022ce31e3',
#     'location': {'address': '1807 Mediterranean Ave',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'crossStreet': '19th Street',
#      'distance': 854,
#      'formattedAddress': ['1807 Mediterranean Ave (19th Street)',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.846027172627124,
#        'lng': -75.98147662979201}],
#      'lat': 36.846027172627124,
#      'lng': -75.98147662979201,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Java Surf Café & Espresso Bar',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4c2f47d266e40f474a92c18b',
#     'location': {'address': 'Atlantic Avenue',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'crossStreet': '10th Street',
#      'distance': 3491,
#      'formattedAddress': ['Atlantic Avenue (10th Street)',
#       'Virginia Beach, VA',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.883645325477346,
#        'lng': -75.98567133549707}],
#      'lat': 36.883645325477346,
#      'lng': -75.98567133549707,
#      'state': 'VA'},
#     'name': 'Beach Coffee Co.',
#     'referralId': 'v-1549903460'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4bbce82f8ec3d13a79671b28',
#     'location': {'address': '1612 Laskin Rd',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 3571,
#      'formattedAddress': ['1612 Laskin Rd',
#       'Virginia Beach, VA 23451',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.85273073,
#        'lng': -76.01751118}],
#      'lat': 36.85273073,
#      'lng': -76.01751118,
#      'postalCode': '23451',
#      'state': 'VA'},
#     'name': 'Starbucks',
#     'referralId': 'v-1549903460'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4ba3ae63f964a520ae5338e3',
#     'location': {'address': '1744 Laskin Rd #24',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 4086,
#      'formattedAddress': ['1744 Laskin Rd #24',
#       'Virginia Beach, VA 23454',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.85151974152343,
#        'lng': -76.02325931237169}],
#      'lat': 36.85151974152343,
#      'lng': -76.02325931237169,
#      'postalCode': '23454',
#      'state': 'VA'},
#     'name': 'Seattles Best Coffee',
#     'referralId': 'v-1549903460'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4c0a41557e3fc9285b3ff382',
#     'location': {'address': 'Laskin Road',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'country': 'United States',
#      'distance': 4816,
#      'formattedAddress': ['Laskin Road',
#       'Virginia Beach, VA 23454',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.84971,
#        'lng': -76.03134}],
#      'lat': 36.84971,
#      'lng': -76.03134,
#      'postalCode': '23454',
#      'state': 'VA'},
#     'name': 'Cars and Coffee',
#     'referralId': 'v-1549903460'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                 categories  \
# 0  [{'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'primary': True, 'shortName': 'Coffee Shop', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_'}, 'id': '4bf58dd8d48988d1e0931735'}]
# 1  [{'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'primary': True, 'shortName': 'Coffee Shop', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_'}, 'id': '4bf58dd8d48988d1e0931735'}]
# 2  [{'name': 'Café', 'pluralName': 'Cafés', 'primary': True, 'shortName': 'Café', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_'}, 'id': '4bf58dd8d48988d16d941735'}]
# 3  [{'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'primary': True, 'shortName': 'Coffee Shop', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_'}, 'id': '4bf58dd8d48988d1e0931735'}]
# 4  [{'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'primary': True, 'shortName': 'Coffee Shop', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_'}, 'id': '4bf58dd8d48988d1e0931735'}]
#
#    hasPerk                        id     location.address location.cc  \
# 0  False    57487afd498e2665b707a63b  607 19th St          US
# 1  False    4b816977f964a52085a430e3  619 18th St          US
# 2  False    4ce6d6419f776ea8f9335422  3198 Pacific Avenur  US
# 3  False    4cb1bedfcbab236a5e24ab73  1005 Atlantic Ave    US
# 4  False    4f321d0319836c91c7b73c2f  3198 Pacific Ave     US
#
#     location.city location.country  location.crossStreet  location.distance  \
# 0  Virginia Beach  United States    Mediterranean Street  882
# 1  Virginia Beach  United States    NaN                   1016
# 2  Virginia Beach  United States    NaN                   843
# 3  Virginia Beach  United States    NaN                   1622
# 4  Virginia Beach  United States    NaN                   704
#
#                                                        location.formattedAddress  \
# 0  [607 19th St (Mediterranean Street), Virginia Beach, VA 23451, United States]
# 1  [619 18th St, Virginia Beach, VA 23451, United States]
# 2  [3198 Pacific Avenur, Virginia Beach, VA 23451, United States]
# 3  [1005 Atlantic Ave, Virginia Beach, VA 23451, United States]
# 4  [3198 Pacific Ave, Virginia Beach, VA 23451, United States]
#
#                                                         location.labeledLatLngs  \
# 0  [{'label': 'display', 'lng': -75.98235051569591, 'lat': 36.846105403127005}]
# 1  [{'label': 'display', 'lng': -75.98315821519844, 'lat': 36.845091600087486}]
# 2  [{'label': 'display', 'lng': -75.98045399704473, 'lat': 36.86015886424331}]
# 3  [{'label': 'display', 'lng': -75.97249804295173, 'lat': 36.838952522337316}]
# 4  [{'label': 'display', 'lng': -75.979261, 'lat': 36.859136}]
#
#    location.lat  location.lng location.postalCode location.state  \
# 0  36.846105    -75.982351     23451               VA
# 1  36.845092    -75.983158     23451               VA
# 2  36.860159    -75.980454     23451               VA
# 3  36.838953    -75.972498     23451               VA
# 4  36.859136    -75.979261     23451               VA
#
#                                   name    referralId venuePage.id
# 0  Three Ships Coffee Bar and Roastery  v-1549903460  NaN
# 1  Bad Ass Coffee                       v-1549903460  35383790
# 2  Perked Up Coffee Cafe                v-1549903460  NaN
# 3  Beach Coffee Co.                     v-1549903460  NaN
# 4  Cape Henry Coffee                    v-1549903460  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name   categories                 address  \
# 0   Three Ships Coffee Bar and Roastery  Coffee Shop  607 19th St
# 1   Bad Ass Coffee                       Coffee Shop  619 18th St
# 2   Perked Up Coffee Cafe                Café         3198 Pacific Avenur
# 3   Beach Coffee Co.                     Coffee Shop  1005 Atlantic Ave
# 4   Cape Henry Coffee                    Coffee Shop  3198 Pacific Ave
# 5   Maui Wowi Hawaiian Coffee            Café         1719 Atlantic Ave
# 6   Belvedere Coffee Shop                Diner        3601 Atlantic Ave
# 7   Starbucks                            Coffee Shop  241 Laskin Road
# 8   Courtyard by Marriott                Hotel        3737 Atlantic Ave
# 9   Java Surf Café & Espresso Bar        Coffee Shop  1807 Mediterranean Ave
# 10  Beach Coffee Co.                     Coffee Shop  Atlantic Avenue
# 11  Starbucks                            Coffee Shop  1612 Laskin Rd
# 12  Seattles Best Coffee                 None         1744 Laskin Rd #24
# 13  Cars and Coffee                      None         Laskin Road
#
#     cc            city        country           crossStreet  distance  \
# 0   US  Virginia Beach  United States  Mediterranean Street  882
# 1   US  Virginia Beach  United States  NaN                   1016
# 2   US  Virginia Beach  United States  NaN                   843
# 3   US  Virginia Beach  United States  NaN                   1622
# 4   US  Virginia Beach  United States  NaN                   704
# 5   US  Virginia Beach  United States  NaN                   822
# 6   US  Virginia Beach  United States  at 36th St            1270
# 7   US  Virginia Beach  United States  NaN                   700
# 8   US  Virginia Beach  United States  NaN                   1435
# 9   US  Virginia Beach  United States  19th Street           854
# 10  US  Virginia Beach  United States  10th Street           3491
# 11  US  Virginia Beach  United States  NaN                   3571
# 12  US  Virginia Beach  United States  NaN                   4086
# 13  US  Virginia Beach  United States  NaN                   4816
#
#                                                                    formattedAddress  \
# 0   [607 19th St (Mediterranean Street), Virginia Beach, VA 23451, United States]
# 1   [619 18th St, Virginia Beach, VA 23451, United States]
# 2   [3198 Pacific Avenur, Virginia Beach, VA 23451, United States]
# 3   [1005 Atlantic Ave, Virginia Beach, VA 23451, United States]
# 4   [3198 Pacific Ave, Virginia Beach, VA 23451, United States]
# 5   [1719 Atlantic Ave, Virginia Beach, VA 23451, United States]
# 6   [3601 Atlantic Ave (at 36th St), Virginia Beach, VA 23451, United States]
# 7   [241 Laskin Road, Virginia Beach, VA 23451, United States]
# 8   [3737 Atlantic Ave, Virginia Beach, VA 23451, United States]
# 9   [1807 Mediterranean Ave (19th Street), Virginia Beach, VA 23451, United States]
# 10  [Atlantic Avenue (10th Street), Virginia Beach, VA, United States]
# 11  [1612 Laskin Rd, Virginia Beach, VA 23451, United States]
# 12  [1744 Laskin Rd #24, Virginia Beach, VA 23454, United States]
# 13  [Laskin Road, Virginia Beach, VA 23454, United States]
#
#                                                                   labeledLatLngs  \
# 0   [{'label': 'display', 'lng': -75.98235051569591, 'lat': 36.846105403127005}]
# 1   [{'label': 'display', 'lng': -75.98315821519844, 'lat': 36.845091600087486}]
# 2   [{'label': 'display', 'lng': -75.98045399704473, 'lat': 36.86015886424331}]
# 3   [{'label': 'display', 'lng': -75.97249804295173, 'lat': 36.838952522337316}]
# 4   [{'label': 'display', 'lng': -75.979261, 'lat': 36.859136}]
# 5   [{'label': 'display', 'lng': -75.97442015, 'lat': 36.846}]
# 6   [{'label': 'display', 'lng': -75.97895220378987, 'lat': 36.8643338388835}]
# 7   [{'label': 'display', 'lng': -75.97897582675576, 'lat': 36.85915482880249}]
# 8   [{'label': 'display', 'lng': -75.9794422, 'lat': 36.8657776}]
# 9   [{'label': 'display', 'lng': -75.98147662979201, 'lat': 36.846027172627124}]
# 10  [{'label': 'display', 'lng': -75.98567133549707, 'lat': 36.883645325477346}]
# 11  [{'label': 'display', 'lng': -76.01751118, 'lat': 36.85273073}]
# 12  [{'label': 'display', 'lng': -76.02325931237169, 'lat': 36.85151974152343}]
# 13  [{'label': 'display', 'lng': -76.03134, 'lat': 36.84971}]
#
#           lat        lng postalCode state                        id
# 0   36.846105 -75.982351  23451      VA    57487afd498e2665b707a63b
# 1   36.845092 -75.983158  23451      VA    4b816977f964a52085a430e3
# 2   36.860159 -75.980454  23451      VA    4ce6d6419f776ea8f9335422
# 3   36.838953 -75.972498  23451      VA    4cb1bedfcbab236a5e24ab73
# 4   36.859136 -75.979261  23451      VA    4f321d0319836c91c7b73c2f
# 5   36.846000 -75.974420  23451      VA    4c7ad1e781bca093a8b60115
# 6   36.864334 -75.978952  23451      VA    4ba65919f964a520034939e3
# 7   36.859155 -75.978976  23451      VA    4b5459abf964a52048b827e3
# 8   36.865778 -75.979442  23451      VA    4c1fe784a34cd13a231a7d74
# 9   36.846027 -75.981477  23451      VA    4b87d477f964a52022ce31e3
# 10  36.883645 -75.985671  NaN        VA    4c2f47d266e40f474a92c18b
# 11  36.852731 -76.017511  23451      VA    4bbce82f8ec3d13a79671b28
# 12  36.851520 -76.023259  23454      VA    4ba3ae63f964a520ae5338e3
# 13  36.849710 -76.031340  23454      VA    4c0a41557e3fc9285b3ff382

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Virginia Beach',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4b5459abf964a52048b827e3' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b5459abf964a52048b827e3?client_id=1GCGK0NEFVQIG41JOZDL1RGYWORMBBSG0SLBIG1GHFWIQBFN&client_secret=KBFKCJFMGSB5XH50VKACBIFANAPYG5O5YWJ4KK3OJQN0UXKU&v=20180929'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['name', 'rating', 'ratingSignals', 'listed', 'dislike', 'stats', 'createdAt', 'categories', 'storeId', 'reasons', 'url', 'shortUrl', 'pageUpdates', 'hours', 'attributes', 'verified', 'tips', 'timeZone', 'contact', 'canonicalUrl', 'location', 'colors', 'photos', 'popular', 'id', 'likes', 'bestPhoto', 'beenHere', 'page', 'ok', 'allowMenuUrlEdit', 'specials', 'price', 'hereNow', 'description', 'inbox', 'ratingColor'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}],
#     'name': 'Price',
#     'summary': '$',
#     'type': 'price'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'type': 'outdoorSeating'},
#    {'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}],
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'type': 'wifi'},
#    {'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'}],
#     'name': 'Menus',
#     'summary': 'Breakfast & Brunch',
#     'type': 'serves'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1332153008,
#   'height': 720,
#   'id': '4f670ab0e4b03a7ce33d2b06',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'suffix': '/gbJut8nlvRCwPl-naiMTVda7WbJBMjP4haNTXGTg_N4.jpg',
#   'visibility': 'public',
#   'width': 540},
#  'canonicalUrl': 'https://foursquare.com/v/starbucks/4b5459abf964a52048b827e3',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'primary': True,
#    'shortName': 'Coffee Shop'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '4f670ab0e4b03a7ce33d2b06', 'value': -8884128},
#   'highlightTextColor': {'photoId': '4f670ab0e4b03a7ce33d2b06', 'value': -1}},
#  'contact': {'facebook': '22092443056',
#   'facebookName': 'Starbucks',
#   'facebookUsername': 'Starbucks',
#   'formattedPhone': '(757) 425-3162',
#   'phone': '7574253162',
#   'twitter': 'starbucks'},
#  'createdAt': 1263819179,
#  'description': '31 Ocean',
#  'dislike': False,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'hours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': True,
#   'richStatus': {'entities': [], 'text': 'Open until 10:30 PM'},
#   'status': 'Open until 10:30 PM',
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '5:30 AM–10:30 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'open': [{'renderedTime': '5:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 AM–9:30 PM'}],
#     'segments': []}]},
#  'id': '4b5459abf964a52048b827e3',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 102,
#   'groups': [{'count': 102, 'items': [], 'type': 'others'}],
#   'summary': '102 Likes'},
#  'listed': {'count': 8,
#   'groups': [{'count': 8,
#     'items': [{'canonicalUrl': 'https://foursquare.com/user/33458297/list/va-beach',
#       'collaborative': False,
#       'createdAt': 1345661978,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 0},
#       'id': '50352c1ae4b0b37a457d408e',
#       'listItems': {'count': 8,
#        'items': [{'createdAt': 1345662061,
#          'id': 'v4b5459abf964a52048b827e3'}]},
#       'name': 'va beach',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1345662359,
#       'url': '/user/33458297/list/va-beach',
#       'user': {'firstName': 'Cheryl',
#        'gender': 'none',
#        'id': '33458297',
#        'lastName': 'Nixon',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/R3C13MHUIQCFBEPS.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/sgilkenson/list/road-trip',
#       'collaborative': False,
#       'createdAt': 1317116330,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 1},
#       'id': '4e8199aa9adf8adb8a4f0b64',
#       'listItems': {'count': 40,
#        'items': [{'createdAt': 1317457119,
#          'id': 'v4b5459abf964a52048b827e3'}]},
#       'name': 'Road Trip',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1368218603,
#       'url': '/sgilkenson/list/road-trip',
#       'user': {'firstName': 'Stephen',
#        'gender': 'male',
#        'id': '784115',
#        'lastName': 'Gilkenson',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/784115-E0OEOOB41T5R5FHM.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/p/att/11852785/list/att-wifi-hot-spots-starbucks-12',
#       'collaborative': False,
#       'createdAt': 1324328545,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 41},
#       'id': '4eefa6610e01899e023233f8',
#       'listItems': {'count': 200,
#        'items': [{'createdAt': 1324614738,
#          'id': 't4ef40455d3e32dc399639d2f'}]},
#       'logView': True,
#       'name': 'AT&T Wi-Fi Hot Spots- Starbucks #12',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1402261446,
#       'url': '/p/att/11852785/list/att-wifi-hot-spots-starbucks-12',
#       'user': {'firstName': 'AT&T',
#        'gender': 'none',
#        'id': '11852785',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/11852785-I454F2WMF3U2VCYF'},
#        'type': 'chain'}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '241 Laskin Road',
#   'cc': 'US',
#   'city': 'Virginia Beach',
#   'country': 'United States',
#   'formattedAddress': ['241 Laskin Road',
#    'Virginia Beach, VA 23451',
#    'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 36.85915482880249,
#     'lng': -75.97897582675576}],
#   'lat': 36.85915482880249,
#   'lng': -75.97897582675576,
#   'postalCode': '23451',
#   'state': 'VA'},
#  'name': 'Starbucks',
#  'ok': False,
#  'page': {'pageInfo': {'banner': 'https://is1.4sqi.net/userpix/EEKNV3AQRAQ4IV3G.png',
#    'description': 'Follow Starbucks on Foursquare to check in and earn great badges. Visit enough stores to become the envy of your friends with the Barista Badge.',
#    'links': {'count': 1, 'items': [{'url': 'http://www.starbucks.com/'}]}},
#   'user': {'bio': '',
#    'contact': {'facebook': '22092443056', 'twitter': 'starbucks'},
#    'firstName': 'Starbucks',
#    'gender': 'none',
#    'homeCity': 'Seattle, WA',
#    'id': '1070527',
#    'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/PM3ZCXLZIG3WZHVC.png'},
#    'tips': {'count': 47},
#    'type': 'chain'}},
#  'pageUpdates': {'count': 47, 'items': []},
#  'photos': {'count': 185,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 185,
#     'items': [{'createdAt': 1332153008,
#       'height': 720,
#       'id': '4f670ab0e4b03a7ce33d2b06',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'suffix': '/gbJut8nlvRCwPl-naiMTVda7WbJBMjP4haNTXGTg_N4.jpg',
#       'user': {'firstName': 'Jeffrey',
#        'gender': 'male',
#        'id': '427688',
#        'lastName': 'Rasmussen',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/QH21MPTWZ3E2KU5W.jpg'}},
#       'visibility': 'public',
#       'width': 540}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'popular': {'isLocalHoliday': False,
#   'isOpen': True,
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'status': 'Likely open',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '7:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'open': [{'renderedTime': '7:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '7:00 AM–8:00 PM'}],
#     'segments': []}]},
#  'price': {'currency': '$', 'message': 'Cheap', 'tier': 1},
#  'rating': 7.6,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 146,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'shortUrl': 'http://4sq.com/aiAxN4',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 32},
#  'storeId': '8888',
#  'timeZone': 'America/New_York',
#  'tips': {'count': 32,
#   'groups': [{'count': 32,
#     'items': [{'agreeCount': 2,
#       'canonicalUrl': 'https://foursquare.com/item/4e108a30d22d759bae5a1f9d',
#       'createdAt': 1309706800,
#       'disagreeCount': 0,
#       'id': '4e108a30d22d759bae5a1f9d',
#       'lang': 'en',
#       'likes': {'count': 5,
#        'groups': [{'count': 5,
#          'items': [{'firstName': 'somebodys',
#            'gender': 'female',
#            'id': '7456357',
#            'lastName': 'some kinda',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/OPKKGSTBG1OPUYZ2.jpg'}},
#           {'firstName': 'Allison',
#            'gender': 'female',
#            'id': '5837874',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/5837874_iTm4e7U0_ngIx4NHxT9PLE_b_0KrvGaftkQNT9zzZwTwx-Aw9-lcXMUxENMQCV031CTzeZsjK.jpg'}}],
#          'type': 'others'}],
#        'summary': '5 likes'},
#       'logView': True,
#       'text': "Slowest Starbucks I've ever been to",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'Leanna',
#        'gender': 'female',
#        'id': '4173929',
#        'lastName': 'Wood',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/5Y4BBVSETWZSOJF3.jpg'}}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'http://www.starbucks.com',
#  'verified': True}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.6

# %%
result['response']['venue']['tips']['count']
# Out:
# 32

# %%
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c61a6971ed2192b5941e52d'},
#  'response': {'tips': {'count': 32,
#    'items': [{'agreeCount': 1,
#      'authorInteractionType': 'liked',
#      'canonicalUrl': 'https://foursquare.com/item/55f59110498e04f2c3e21c5f',
#      'createdAt': 1442156816,
#      'disagreeCount': 0,
#      'id': '55f59110498e04f2c3e21c5f',
#      'lang': 'en',
#      'lastUpvoteTimestamp': 1545852557,
#      'lastVoteText': 'Upvoted Dec 26, 2018',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'photo': {'createdAt': 1442156819,
#       'height': 1440,
#       'id': '55f59113498e2717395b5d44',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'suffix': '/23575557_aySlqN9KYKwZMzQdkSmBCESJCjCHCZFEi1Fao8619yY.jpg',
#       'visibility': 'public',
#       'width': 1920},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/23575557_aySlqN9KYKwZMzQdkSmBCESJCjCHCZFEi1Fao8619yY.jpg',
#      'text': "My gosh this place draws a long line quick!😧 The weather is good enough to drink/eat outside. It's also pretty cool temperature wise indoors. My #Latte was delicious, nice place to take your date. ☕️",
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Angelo',
#       'gender': 'male',
#       'id': '23575557',
#       'lastName': 'Di Natale',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/23575557_Vxr5wr8X_nbzbmblRASHDEU7ZAsLv0k-9KYTieQbdJouX9eSzg4XY4yt3fHRFHaUBqkX9aoTt.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['photo', 'canonicalUrl', 'agreeCount', 'lastVoteText', 'authorInteractionType', 'id', 'createdAt', 'user', 'todo', 'lang', 'type', 'text', 'lastUpvoteTimestamp', 'logView', 'disagreeCount', 'likes', 'photourl'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                                       text  \
# 0  My gosh this place draws a long line quick!😧 The weather is good enough to drink/eat outside. It's also pretty cool temperature wise indoors. My #Latte was delicious, nice place to take your date. ☕️
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  1           0              55f59110498e04f2c3e21c5f  Angelo
#
#   user.lastName user.gender   user.id
# 0  Di Natale     male        23575557

# %%
city = 'Pompano Beach'
geolocator = Nominatim()
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 26.2378597 -80.1247667

# %%
search_query = 'Coffee'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1GCGK0NEFVQIG41JOZDL1RGYWORMBBSG0SLBIG1GHFWIQBFN&client_secret=KBFKCJFMGSB5XH50VKACBIFANAPYG5O5YWJ4KK3OJQN0UXKU&ll=26.2378597,-80.1247667&v=20180929&query=Coffee&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c61a6b2351e3d194fd76e46'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'delivery': {'id': '557257',
#      'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'grubhub'},
#      'url': 'https://www.grubhub.com/restaurant/calusa-coffee-roasters-161-e-commercial-blvd-fort-lauderdale/557257?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=557257'},
#     'hasPerk': False,
#     'id': '561d2581498ee5be35171393',
#     'location': {'address': '161 E Commercial Blvd',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'distance': 5845,
#      'formattedAddress': ['161 E Commercial Blvd',
#       'Fort Lauderdale, FL 33334',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.188696003134485,
#        'lng': -80.14533512628987}],
#      'lat': 26.188696003134485,
#      'lng': -80.14533512628987,
#      'postalCode': '33334',
#      'state': 'FL'},
#     'name': 'Calusa Coffee Roasters',
#     'referralId': 'v-1549903538',
#     'venuePage': {'id': '146701814'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '59be9d5e2079551e2b9d17b2',
#     'location': {'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'distance': 4880,
#      'formattedAddress': ['Fort Lauderdale, FL 33309', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.202628825623375,
#        'lng': -80.15385356040811}],
#      'lat': 26.202628825623375,
#      'lng': -80.15385356040811,
#      'postalCode': '33309',
#      'state': 'FL'},
#     'name': 'Starbucks Coffee',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'primary': True,
#       'shortName': 'Desserts'}],
#     'hasPerk': False,
#     'id': '4e5436f81850048f642da531',
#     'location': {'cc': 'US',
#      'city': 'Pompano Beach',
#      'country': 'United States',
#      'distance': 2296,
#      'formattedAddress': ['Pompano Beach, FL 33062', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.231684356442894,
#        'lng': -80.10282039642334}],
#      'lat': 26.231684356442894,
#      'lng': -80.10282039642334,
#      'postalCode': '33062',
#      'state': 'FL'},
#     'name': 'Beach Roast- Gourmet Cakes & Desserts / Caribbean & Organic Coffees                                                              Home Delivery  / Mail Order  /  Wholesale',
#     'referralId': 'v-1549903538',
#     'venuePage': {'id': '34930870'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b0ca736f964a520994023e3',
#     'location': {'address': '1800 N Federal Hwy',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'country': 'United States',
#      'distance': 3113,
#      'formattedAddress': ['1800 N Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.254771744411375,
#        'lng': -80.09993382956327}],
#      'lat': 26.254771744411375,
#      'lng': -80.09993382956327,
#      'postalCode': '33062',
#      'state': 'FL'},
#     'name': 'Starbucks',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '4e551eb518508c109233b4c6',
#     'location': {'address': '655 N Federal Hwy',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'country': 'United States',
#      'distance': 2185,
#      'formattedAddress': ['655 N Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.23726609433151,
#        'lng': -80.1028847694397}],
#      'lat': 26.23726609433151,
#      'lng': -80.1028847694397,
#      'postalCode': '33062',
#      'state': 'FL'},
#     'name': 'BeachRoast Bake Shop & Coffee Roastery (Bakery)',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4af080acf964a520b5dc21e3',
#     'location': {'address': '423 S. Federal Highway',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'country': 'United States',
#      'distance': 2398,
#      'formattedAddress': ['423 S. Federal Highway',
#       'Pompano Beach, FL 33062',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.22872271,
#        'lng': -80.10301395}],
#      'lat': 26.22872271,
#      'lng': -80.10301395,
#      'postalCode': '33062',
#      'state': 'FL'},
#     'name': 'Starbucks',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4ba22623f964a5204adf37e3',
#     'location': {'address': '1631 S Cypress Rd',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'country': 'United States',
#      'crossStreet': 'McNab',
#      'distance': 3150,
#      'formattedAddress': ['1631 S Cypress Rd (McNab)',
#       'Pompano Beach, FL 33060',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.209585743855826,
#        'lng': -80.12333393096924}],
#      'lat': 26.209585743855826,
#      'lng': -80.12333393096924,
#      'postalCode': '33060',
#      'state': 'FL'},
#     'name': 'boomerang coffee',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '58a622eb0a3d5449dcb753e0',
#     'location': {'address': '2411 N Federal Hwy',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'country': 'United States',
#      'distance': 3628,
#      'formattedAddress': ['2411 N Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.2612944444444,
#        'lng': -80.0994988888889}],
#      'lat': 26.2612944444444,
#      'lng': -80.0994988888889,
#      'postalCode': '33062',
#      'state': 'FL'},
#     'name': 'Allegro Coffee Company',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f32641419836c91c7d32f60',
#     'location': {'address': '6472 NW 5th Way',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'distance': 4288,
#      'formattedAddress': ['6472 NW 5th Way',
#       'Fort Lauderdale, FL 33309',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.207023,
#        'lng': -80.15051}],
#      'lat': 26.207023,
#      'lng': -80.15051,
#      'postalCode': '33309',
#      'state': 'FL'},
#     'name': 'Manhattan Gourmet Coffee',
#     'referralId': 'v-1549903538',
#     'venuePage': {'id': '76423579'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'primary': True,
#       'shortName': 'Latin American'}],
#     'hasPerk': False,
#     'id': '4f71e862e4b03b7fbb2d81e4',
#     'location': {'address': '6310 Powerline Rd',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'crossStreet': 'NW 63rd St',
#      'distance': 4675,
#      'formattedAddress': ['6310 Powerline Rd (NW 63rd St)',
#       'Fort Lauderdale, FL 33309',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.205691326539085,
#        'lng': -80.15487019806336}],
#      'lat': 26.205691326539085,
#      'lng': -80.15487019806336,
#      'postalCode': '33309',
#      'state': 'FL'},
#     'name': "Ricky's Coffee Shop",
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f3257f319836c91c7ce7069',
#     'location': {'address': '6310 Powerline Rd',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'distance': 4844,
#      'formattedAddress': ['6310 Powerline Rd',
#       'Fort Lauderdale, FL 33309',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.204236,
#        'lng': -80.155567}],
#      'lat': 26.204236,
#      'lng': -80.155567,
#      'postalCode': '33309',
#      'state': 'FL'},
#     'name': 'Manhattan Gourmet Coffee',
#     'referralId': 'v-1549903538'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4bfeb45e34ced13ad5f537b3',
#     'location': {'address': 'sample road',
#      'cc': 'US',
#      'city': 'Lighthouse PT',
#      'country': 'United States',
#      'crossStreet': 'federal highway',
#      'distance': 5236,
#      'formattedAddress': ['sample road (federal highway)',
#       'Lighthouse PT, FL 33064',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.272529,
#        'lng': -80.08931}],
#      'lat': 26.272529,
#      'lng': -80.08931,
#      'postalCode': '33064',
#      'state': 'FL'},
#     'name': 'daily grind coffee shop',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '53aef269498ec970f3cf1265',
#     'location': {'address': '3704 N. Ocean Blvd',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'distance': 7610,
#      'formattedAddress': ['3704 N. Ocean Blvd',
#       'Fort Lauderdale, FL 33308',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.173383444326404,
#        'lng': -80.09943507413925}],
#      'lat': 26.173383444326404,
#      'lng': -80.09943507413925,
#      'postalCode': '33308',
#      'state': 'FL'},
#     'name': 'Starbucks',
#     'referralId': 'v-1549903538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'primary': True,
#       'shortName': 'Community College'}],
#     'hasPerk': False,
#     'id': '4b29518cf964a520d59c24e3',
#     'location': {'address': '1000 Coconut Creek Blvd',
#      'cc': 'US',
#      'city': 'Coconut Creek',
#      'country': 'United States',
#      'distance': 4874,
#      'formattedAddress': ['1000 Coconut Creek Blvd',
#       'Coconut Creek, FL 33066',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.240689821714884,
#        'lng': -80.17348835186554}],
#      'lat': 26.240689821714884,
#      'lng': -80.17348835186554,
#      'postalCode': '33066',
#      'state': 'FL'},
#     'name': 'Broward College North Campus',
#     'referralId': 'v-1549903538',
#     'venuePage': {'id': '64256277'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f32a1ac19836c91c7ea98dd',
#     'location': {'address': '4711 NE 18th Ter',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'country': 'United States',
#      'distance': 5867,
#      'formattedAddress': ['4711 NE 18th Ter',
#       'Fort Lauderdale, FL 33308',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.185221,
#        'lng': -80.121678}],
#      'lat': 26.185221,
#      'lng': -80.121678,
#      'postalCode': '33308',
#      'state': 'FL'},
#     'name': 'Starbucks Coffee',
#     'referralId': 'v-1549903538'}]}}

# %%
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.shape
# Out:
# (15, 24)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                                                                                                                                           name  \
# 0   Calusa Coffee Roasters
# 1   Starbucks Coffee
# 2   Beach Roast- Gourmet Cakes & Desserts / Caribbean & Organic Coffees                                                              Home Delivery  / Mail Order  /  Wholesale
# 3   Starbucks
# 4   BeachRoast Bake Shop & Coffee Roastery (Bakery)
# 5   Starbucks
# 6   boomerang coffee
# 7   Allegro Coffee Company
# 8   Manhattan Gourmet Coffee
# 9   Ricky's Coffee Shop
# 10  Manhattan Gourmet Coffee
# 11  daily grind coffee shop
# 12  Starbucks
# 13  Broward College North Campus
# 14  Starbucks Coffee
#
#                    categories                  address  cc             city  \
# 0   Coffee Shop                161 E Commercial Blvd    US  Fort Lauderdale
# 1   Coffee Shop                NaN                      US  Fort Lauderdale
# 2   Dessert Shop               NaN                      US  Pompano Beach
# 3   Coffee Shop                1800 N Federal Hwy       US  Pompano Beach
# 4   Café                       655 N Federal Hwy        US  Pompano Beach
# 5   Coffee Shop                423 S. Federal Highway   US  Pompano Beach
# 6   Coffee Shop                1631 S Cypress Rd        US  Pompano Beach
# 7   Coffee Shop                2411 N Federal Hwy       US  Pompano Beach
# 8   Coffee Shop                6472 NW 5th Way          US  Fort Lauderdale
# 9   Latin American Restaurant  6310 Powerline Rd        US  Fort Lauderdale
# 10  Coffee Shop                6310 Powerline Rd        US  Fort Lauderdale
# 11  None                       sample road              US  Lighthouse PT
# 12  Coffee Shop                3704 N. Ocean Blvd       US  Fort Lauderdale
# 13  Community College          1000 Coconut Creek Blvd  US  Coconut Creek
# 14  Coffee Shop                4711 NE 18th Ter         US  Fort Lauderdale
#
#           country      crossStreet  distance  \
# 0   United States  NaN              5845
# 1   United States  NaN              4880
# 2   United States  NaN              2296
# 3   United States  NaN              3113
# 4   United States  NaN              2185
# 5   United States  NaN              2398
# 6   United States  McNab            3150
# 7   United States  NaN              3628
# 8   United States  NaN              4288
# 9   United States  NW 63rd St       4675
# 10  United States  NaN              4844
# 11  United States  federal highway  5236
# 12  United States  NaN              7610
# 13  United States  NaN              4874
# 14  United States  NaN              5867
#
#                                                               formattedAddress  \
# 0   [161 E Commercial Blvd, Fort Lauderdale, FL 33334, United States]
# 1   [Fort Lauderdale, FL 33309, United States]
# 2   [Pompano Beach, FL 33062, United States]
# 3   [1800 N Federal Hwy, Pompano Beach, FL 33062, United States]
# 4   [655 N Federal Hwy, Pompano Beach, FL 33062, United States]
# 5   [423 S. Federal Highway, Pompano Beach, FL 33062, United States]
# 6   [1631 S Cypress Rd (McNab), Pompano Beach, FL 33060, United States]
# 7   [2411 N Federal Hwy, Pompano Beach, FL 33062, United States]
# 8   [6472 NW 5th Way, Fort Lauderdale, FL 33309, United States]
# 9   [6310 Powerline Rd (NW 63rd St), Fort Lauderdale, FL 33309, United States]
# 10  [6310 Powerline Rd, Fort Lauderdale, FL 33309, United States]
# 11  [sample road (federal highway), Lighthouse PT, FL 33064, United States]
# 12  [3704 N. Ocean Blvd, Fort Lauderdale, FL 33308, United States]
# 13  [1000 Coconut Creek Blvd, Coconut Creek, FL 33066, United States]
# 14  [4711 NE 18th Ter, Fort Lauderdale, FL 33308, United States]
#
#                                                                   labeledLatLngs  \
# 0   [{'label': 'display', 'lng': -80.14533512628987, 'lat': 26.188696003134485}]
# 1   [{'label': 'display', 'lng': -80.15385356040811, 'lat': 26.202628825623375}]
# 2   [{'label': 'display', 'lng': -80.10282039642334, 'lat': 26.231684356442894}]
# 3   [{'label': 'display', 'lng': -80.09993382956327, 'lat': 26.254771744411375}]
# 4   [{'label': 'display', 'lng': -80.1028847694397, 'lat': 26.23726609433151}]
# 5   [{'label': 'display', 'lng': -80.10301395, 'lat': 26.22872271}]
# 6   [{'label': 'display', 'lng': -80.12333393096924, 'lat': 26.209585743855826}]
# 7   [{'label': 'display', 'lng': -80.0994988888889, 'lat': 26.2612944444444}]
# 8   [{'label': 'display', 'lng': -80.15051, 'lat': 26.207023}]
# 9   [{'label': 'display', 'lng': -80.15487019806336, 'lat': 26.205691326539085}]
# 10  [{'label': 'display', 'lng': -80.155567, 'lat': 26.204236}]
# 11  [{'label': 'display', 'lng': -80.08931, 'lat': 26.272529}]
# 12  [{'label': 'display', 'lng': -80.09943507413925, 'lat': 26.173383444326404}]
# 13  [{'label': 'display', 'lng': -80.17348835186554, 'lat': 26.240689821714884}]
# 14  [{'label': 'display', 'lng': -80.121678, 'lat': 26.185221}]
#
#           lat        lng postalCode state                        id
# 0   26.188696 -80.145335  33334      FL    561d2581498ee5be35171393
# 1   26.202629 -80.153854  33309      FL    59be9d5e2079551e2b9d17b2
# 2   26.231684 -80.102820  33062      FL    4e5436f81850048f642da531
# 3   26.254772 -80.099934  33062      FL    4b0ca736f964a520994023e3
# 4   26.237266 -80.102885  33062      FL    4e551eb518508c109233b4c6
# 5   26.228723 -80.103014  33062      FL    4af080acf964a520b5dc21e3
# 6   26.209586 -80.123334  33060      FL    4ba22623f964a5204adf37e3
# 7   26.261294 -80.099499  33062      FL    58a622eb0a3d5449dcb753e0
# 8   26.207023 -80.150510  33309      FL    4f32641419836c91c7d32f60
# 9   26.205691 -80.154870  33309      FL    4f71e862e4b03b7fbb2d81e4
# 10  26.204236 -80.155567  33309      FL    4f3257f319836c91c7ce7069
# 11  26.272529 -80.089310  33064      FL    4bfeb45e34ced13ad5f537b3
# 12  26.173383 -80.099435  33308      FL    53aef269498ec970f3cf1265
# 13  26.240690 -80.173488  33066      FL    4b29518cf964a520d59c24e3
# 14  26.185221 -80.121678  33308      FL    4f32a1ac19836c91c7ea98dd

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Pompano Beach',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4af080acf964a520b5dc21e3' # Nearest starbucks
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4af080acf964a520b5dc21e3?client_id=1GCGK0NEFVQIG41JOZDL1RGYWORMBBSG0SLBIG1GHFWIQBFN&client_secret=KBFKCJFMGSB5XH50VKACBIFANAPYG5O5YWJ4KK3OJQN0UXKU&v=20180929'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['name', 'rating', 'ratingSignals', 'listed', 'dislike', 'stats', 'createdAt', 'categories', 'storeId', 'reasons', 'url', 'shortUrl', 'pageUpdates', 'hours', 'attributes', 'verified', 'tips', 'timeZone', 'contact', 'canonicalUrl', 'location', 'colors', 'photos', 'popular', 'id', 'likes', 'bestPhoto', 'beenHere', 'page', 'ok', 'allowMenuUrlEdit', 'specials', 'price', 'hereNow', 'description', 'inbox', 'ratingColor'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. Discover & Visa)'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'type': 'outdoorSeating'},
#    {'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}],
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'type': 'wifi'},
#    {'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'}],
#     'name': 'Menus',
#     'summary': 'Breakfast',
#     'type': 'serves'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1360681169,
#   'height': 960,
#   'id': '511a58d1e4b0030487f30121',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'suffix': '/15208664_OABwsdJqGi97y8xCZ3UQqsfGzvGJrtYGLu4X7H8oA2s.jpg',
#   'visibility': 'public',
#   'width': 720},
#  'canonicalUrl': 'https://foursquare.com/v/starbucks/4af080acf964a520b5dc21e3',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'primary': True,
#    'shortName': 'Coffee Shop'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '511a58d1e4b0030487f30121',
#    'value': -15198184},
#   'highlightTextColor': {'photoId': '511a58d1e4b0030487f30121', 'value': -1}},
#  'contact': {'facebook': '22092443056',
#   'facebookName': 'Starbucks',
#   'facebookUsername': 'Starbucks',
#   'formattedPhone': '(954) 545-3431',
#   'phone': '9545453431',
#   'twitter': 'starbucks'},
#  'createdAt': 1257275564,
#  'description': 'Pompano Plaza',
#  'dislike': False,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'hours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': True,
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'status': 'Open until 10:00 PM',
#   'timeframes': [{'days': 'Mon–Fri',
#     'includesToday': True,
#     'open': [{'renderedTime': '5:00 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '5:30 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'id': '4af080acf964a520b5dc21e3',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 68,
#   'groups': [{'count': 68, 'items': [], 'type': 'others'}],
#   'summary': '68 Likes'},
#  'listed': {'count': 7,
#   'groups': [{'count': 7,
#     'items': [{'canonicalUrl': 'https://foursquare.com/manonboisvert/list/starbucks-around-the-world',
#       'collaborative': False,
#       'createdAt': 1363482443,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 10},
#       'id': '5145174be4b0c80a356483db',
#       'listItems': {'count': 101,
#        'items': [{'createdAt': 1384398097,
#          'id': 'v4af080acf964a520b5dc21e3'}]},
#       'name': 'Starbucks around the world',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1410148785,
#       'url': '/manonboisvert/list/starbucks-around-the-world',
#       'user': {'firstName': 'Manon B 🌈🌺😍',
#        'gender': 'female',
#        'id': '5499520',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/5499520-PVYFHV0RKJIPDT2M.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/patti1313/list/drinks',
#       'collaborative': False,
#       'createdAt': 1338587006,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 3},
#       'id': '4fc9377ee4b0400ad2129c1b',
#       'listItems': {'count': 49,
#        'items': [{'createdAt': 1384637811,
#          'id': 'v4af080acf964a520b5dc21e3'}]},
#       'name': 'Drinks',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1406334706,
#       'url': '/patti1313/list/drinks',
#       'user': {'firstName': 'Patti',
#        'gender': 'female',
#        'id': '28369735',
#        'lastName': 'P.',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/28369735-5FBEBMYY1T1CU2IE.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/user/12893880/list/mustvisit-food-in-pompano-beach',
#       'collaborative': False,
#       'createdAt': 1317297710,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 1},
#       'id': '4e845e2e7bebd842c95097bf',
#       'listItems': {'count': 3,
#        'items': [{'createdAt': 1317297710,
#          'id': 'v4af080acf964a520b5dc21e3'}]},
#       'name': 'Must-visit Food in Pompano Beach',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1317297710,
#       'url': '/user/12893880/list/mustvisit-food-in-pompano-beach',
#       'user': {'firstName': 'Mary',
#        'gender': 'female',
#        'id': '12893880',
#        'lastName': 'Keiser',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W1FPIRJGV35VA2BI.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/p/att/11852785/list/att-wifi-hot-spots--starbucks-9',
#       'collaborative': False,
#       'createdAt': 1323720262,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 83},
#       'id': '4ee65e46a69d89905ddba756',
#       'listItems': {'count': 198,
#        'items': [{'createdAt': 1323805080,
#          'id': 't4ee7a99fb634ba846b99fe3b'}]},
#       'logView': True,
#       'name': 'AT&T Wi-Fi Hot Spots - Starbucks #9',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1405708657,
#       'url': '/p/att/11852785/list/att-wifi-hot-spots--starbucks-9',
#       'user': {'firstName': 'AT&T',
#        'gender': 'none',
#        'id': '11852785',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/11852785-I454F2WMF3U2VCYF'},
#        'type': 'chain'}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '423 S. Federal Highway',
#   'cc': 'US',
#   'city': 'Pompano Beach',
#   'country': 'United States',
#   'formattedAddress': ['423 S. Federal Highway',
#    'Pompano Beach, FL 33062',
#    'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 26.22872271,
#     'lng': -80.10301395}],
#   'lat': 26.22872271,
#   'lng': -80.10301395,
#   'postalCode': '33062',
#   'state': 'FL'},
#  'name': 'Starbucks',
#  'ok': False,
#  'page': {'pageInfo': {'banner': 'https://is1.4sqi.net/userpix/EEKNV3AQRAQ4IV3G.png',
#    'description': 'Follow Starbucks on Foursquare to check in and earn great badges. Visit enough stores to become the envy of your friends with the Barista Badge.',
#    'links': {'count': 1, 'items': [{'url': 'http://www.starbucks.com/'}]}},
#   'user': {'bio': '',
#    'contact': {'facebook': '22092443056', 'twitter': 'starbucks'},
#    'firstName': 'Starbucks',
#    'gender': 'none',
#    'homeCity': 'Seattle, WA',
#    'id': '1070527',
#    'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/PM3ZCXLZIG3WZHVC.png'},
#    'tips': {'count': 47},
#    'type': 'chain'}},
#  'pageUpdates': {'count': 49, 'items': []},
#  'photos': {'count': 91,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 91,
#     'items': [{'createdAt': 1360681169,
#       'height': 960,
#       'id': '511a58d1e4b0030487f30121',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'suffix': '/15208664_OABwsdJqGi97y8xCZ3UQqsfGzvGJrtYGLu4X7H8oA2s.jpg',
#       'user': {'firstName': 'Ashley',
#        'gender': 'female',
#        'id': '15208664',
#        'lastName': 'Cline',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/4ROFAQ3MPUYNDE1P.jpg'}},
#       'visibility': 'public',
#       'width': 720}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'popular': {'isLocalHoliday': False,
#   'isOpen': True,
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'status': 'Likely open',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–6:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–5:00 PM'},
#      {'renderedTime': '7:00 PM–8:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–4:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '7:00 AM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '7:00 AM–6:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–5:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#  'rating': 8.2,
#  'ratingColor': '73CF42',
#  'ratingSignals': 95,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'shortUrl': 'http://4sq.com/4u4zJx',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 21},
#  'storeId': '8476',
#  'timeZone': 'America/New_York',
#  'tips': {'count': 21,
#   'groups': [{'count': 21,
#     'items': [{'agreeCount': 7,
#       'canonicalUrl': 'https://foursquare.com/item/4e652becb61cd78089bb5826',
#       'createdAt': 1315253228,
#       'disagreeCount': 0,
#       'id': '4e652becb61cd78089bb5826',
#       'lang': 'en',
#       'likes': {'count': 7,
#        'groups': [{'count': 7,
#          'items': [{'firstName': 'Sheri Fresonke',
#            'gender': 'female',
#            'id': '4301792',
#            'lastName': 'Harper',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/F04Y0JNEWQAKHJCT.jpg'}},
#           {'firstName': 'Tom',
#            'gender': 'male',
#            'id': '10612172',
#            'lastName': 'Laing',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/L5DB5FGEHI4SAWEI.jpg'}},
#           {'firstName': 'rosario',
#            'gender': 'male',
#            'id': '45855208',
#            'lastName': 'strano',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/XAKYEDXLEALR4QKX.jpg'}},
#           {'firstName': 'Manlio',
#            'gender': 'male',
#            'id': '10088061',
#            'lastName': 'Mannozzi',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/T5PFTB12ATKCZJPX.jpg'}}],
#          'type': 'others'}],
#        'summary': '7 likes'},
#       'logView': True,
#       'text': 'Try the coffee',
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'Mac',
#        'gender': 'male',
#        'id': '2960638',
#        'lastName': 'McLaughlin',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2960638-OH4GHXQNFFLCJLPJ.jpg'}}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'http://www.starbucks.com',
#  'verified': True}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %%
result['response']['venue']['tips']['count']
# Out:
# 21

# %%
limit = 25 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c61a76e6a60712d32e31b5c'},
#  'response': {'tips': {'count': 21,
#    'items': [{'agreeCount': 4,
#      'canonicalUrl': 'https://foursquare.com/item/5112675be4b0014add4b1db0',
#      'createdAt': 1360160603,
#      'disagreeCount': 0,
#      'id': '5112675be4b0014add4b1db0',
#      'lang': 'en',
#      'lastUpvoteTimestamp': 1545776621,
#      'lastVoteText': 'Upvoted Dec 25, 2018',
#      'likes': {'count': 2,
#       'groups': [{'count': 2,
#         'items': [{'firstName': 'Ahmed',
#           'gender': 'male',
#           'id': '146691036',
#           'lastName': '...',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/146691036_JKdY27Gl_RyQlcH0szWQ2bcZK1mYLEV198c9KAjO5E6kk5YtciSmmacW5XlUHtYXVQe4cm5KR.jpg'}},
#          {'firstName': 'Chris',
#           'gender': 'male',
#           'id': '29119069',
#           'lastName': 'Thomas',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/L55ZM1NSEEEWWPW0.jpg'}}],
#         'type': 'others'}],
#       'summary': '2 likes'},
#      'logView': True,
#      'text': 'Best Starbucks around, Chris is a great barista and all the other ones are so kind and helpful as well!',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Mary',
#       'gender': 'female',
#       'id': '39118745',
#       'lastName': 'Allen',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/TEXR5UWN1WPRBS40.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['canonicalUrl', 'agreeCount', 'id', 'createdAt', 'user', 'todo', 'lang', 'type', 'text', 'lastUpvoteTimestamp', 'logView', 'disagreeCount', 'likes', 'lastVoteText'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                       text  \
# 0  Best Starbucks around, Chris is a great barista and all the other ones are so kind and helpful as well!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  4           0              5112675be4b0014add4b1db0  Mary
#
#   user.lastName user.gender   user.id
# 0  Allen         female      39118745
